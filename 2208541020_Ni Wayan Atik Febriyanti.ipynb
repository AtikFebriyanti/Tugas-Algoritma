# %%
############################################################################
# perintah print digunakan untuk mencetak kata yang ada didalam tanda kurung
# tanda petik harus sama dikedua sisi ,jika berbeda maka hasilnya akan error
############################################################################
print('Ni Wayan Atik Febriyanti')
# Out:
# Ni Wayan Atik Febriyanti

# %%
print("Mata Kuliah Algoritma dan Struktur Data ")
# Out:
# Mata Kuliah Algoritma dan Struktur Data

# %%
buku = 10
pensil = 5
tas = 4
print(buku)
print(pensil)
print(tas)
# Out:
# 10
# 5
# 4

# %%
################################################################################
#perintah input dapat digunakan untuk mendapat kan suatu informasi dari pengguna 
################################################################################
nama =input("siapakah nama anda ?")
kegiatan = input ('apakah kegiatan anda ,' + nama + '?')
print ("semangat " + kegiatan + " yaa " +  nama + ",jangan lupa makan hehehehehehehe" )
# Out:
# siapakah nama anda ?atik
# apakah kegiatan anda ,atik?kuliah
# semangat kuliah yaa atik,jangan lupa makan hehehehehehehe

# %%
###########################################################################
#int = bilangan bulat
#float =bilangan desimal
#string = teks dan karakter 
###########################################################################
buku_di_tas = input("Berapakah jumlah buku didalam tas anda? ")
buku_di_rumah = input("Berapakah jumlah buku yang ada di rumah? ")
total_buku = int(buku_di_tas) + int(buku_di_rumah)
print("Total buku anda adalah"  + str(total_buku))
# Out:
# Berapakah jumlah buku didalam tas anda? 5
# Berapakah jumlah buku yang ada di rumah? 3
# Total buku anda adalah8

# %%
###################################################################################################################################
# Formatted String biasanya digunakan untuk mempermudah untuk penulisan nilai variabel yang akan dicetak menggunakan perintah print
################################################################################################################################### 
nama = (" Ir Soekarno")
jabatan = ('Presiden')
negara = ('Indonesia ')
print(nama + ' adalah merupakan '+ jabatan + ' pertama ' +' di '+ negara )
# Out:
#  Ir Soekarno adalah merupakan Presiden pertama  di Indonesia

# %%
##################################################################################
# penggunaan tanda petik harus sama antara kanan dan kiri agar tidak terjadi error 
##################################################################################
print(f'{nama } adalah merupakan {jabatan} pertama di {negara}')
# Out:
#  Ir Soekarno adalah merupakan Presiden pertama di Indonesia

# %%
print(f"{nama} adalah merupakan {jabatan} pertama di {negara}")
# Out:
#  Ir Soekarno adalah merupakan Presiden pertama di Indonesia
